# %% [markdown]
# # Information retvieval using sentence transformers in PyTorch
#
# In this notebook, we build a retriever-reranker ensemble
# 1. Retriever (a model that for a given topic outputs *a significant number* of content items, many of which are not really relevant) stage
# - First we fine-tune a pretrained sentence transformer model **'paraphrase-distilroberta-base-v2'** from **'HuggingFace Library'** in an unsupervised fashion, on a set of *positive* (topic title, content item title) pairs (`uns_train.csv`), that is, the corresponding topic and content item are known to be related.
# - Then, using the fine-tuned model, we map all topic and content item titles to 768-dimensional real-valued vectors and split content title vectors into clusters of 30 nearest neighbors using the KNN algorithm.
# - Next, for every topic we compose a list of its content item neighbors and split the list of topics into a training set (`train_topics.csv`) and a test set (`test_topics.csv`).
# - Finally, for every topic in the `train_topics.csv` list, we label its neighboring content items with either 0, or 1, based on the known correlation with the topic. The result is a training dataset (`sup_train.csv`) for the reranker model - this is the output of the retriever.
# 2. Reranker stage
# - We construct a custom classification (0 or 1) model based on **'paraphrase-multilingual-mpnet-base-v2'** from **'HuggingFace Library'** and train it on the `sup_train.csv` dataset. This is the reranker model: for every pair (topic, content item) it predicts if the corresponding topic title and content item title are related (outputs 1) or not related (outputs 0).
# - Finally, we test the reranker model: for every topic in `test_topics.csv` we use the reranker model to drop irrelevant content items that were originally output by the retriver.
#
# Note: The notebook was tested with `ml.m5.large (4 vCPU + 16 GiB)` instance and `Python3 (PyTorch 1.6 Python 3.6 CPU Optimized)` kernel.

# %% [markdown]
# ## Setup
# Update sagemaker package and restart the kernel.

# %%
# !pip install -U sagemaker -q
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.6m/UNKNOWN
# sysconfig: /opt/conda/include/python3.6m
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import sagemaker
sagemaker.__version__
# Out:
# '2.117.0'

# %%
# !pip install sentence_transformers -q
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.6m/UNKNOWN
# sysconfig: /opt/conda/include/python3.6m
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import boto3, os, sagemaker
import json

sess = sagemaker.Session()
bucket = sess.default_bucket() 
prefix = 'sentencetransformer/input'
role = sagemaker.get_execution_role()

# %% [markdown]
# ## Load the data and create a training set `uns_dataset` for the encoder. Save it to `uns_train.csv`

# %%
# %%time

import pandas as pd

DATA_PATH = "./Kaggle/"

topics_df = pd.read_csv(DATA_PATH + "topics.csv")
content_df = pd.read_csv(DATA_PATH + "content.csv")
correlations_df = pd.read_csv(DATA_PATH + "correlations.csv")
sample_sub_df = pd.read_csv(DATA_PATH + "sample_submission.csv")
# Out:
# CPU times: user 6.87 s, sys: 975 ms, total: 7.84 s
# Wall time: 11.8 s

# %%
def build_uns_dataset():
    topics = topics_df[topics_df['title'].notna()]
    content = content_df[content_df['title'].notna()]
    
    topics = topics[topics['language'] == 'en']
    content = content[content['language'] == 'en']
    
    print(' ')
    print('-' * 50)
    print(f"topics.shape: {topics.shape}")
    print(f"content.shape: {content.shape}")
    
    topics = topics.rename(columns = {"id": "topic_id",
                                         "title": "topic_title",
                                         "description": "topic_description",
                                         "language": "topic_language"
                                        }
                             )
    
    content = content.rename(columns = {"id": "content_id",
                                           "title": "content_title",
                                           "description": "content_description",
                                           "text": "content_text",
                                           "language": "content_language"
                                          }
                               )
    correlations_df["content_id"] = correlations_df["content_ids"].str.split(" ")
    corr = correlations_df.explode("content_id").drop(columns = ["content_ids"])
    
    corr = corr.merge(topics, how = "left", on = "topic_id")
    corr = corr.merge(content, how = "left", on = "content_id")
    corr = corr[corr['topic_title'].notna()]
    corr = corr[corr['content_title'].notna()]
    
    corr["set"] = corr[["topic_title", "content_title"]].values.tolist()
    dataset = pd.DataFrame(corr["set"])
    
    return dataset

# %%
uns_dataset.to_csv('uns_train.csv')

boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'uns_train.csv')).upload_file('uns_train.csv')

uns_data_input_path = "s3://{}/{}/".format(bucket, prefix)
uns_data_input_path
# Out:
# 's3://sagemaker-us-east-1-852055550328/sentencetransformer/input/'

# %% [markdown]
# ## Choose a pretrained sentence transformer as an encoder (test on 20% of `uns_dataset`)

# %%
from tqdm import tqdm
from sklearn.model_selection import train_test_split

uns_train , uns_test = train_test_split(uns_dataset, test_size = 0.2)

def create_test_sentences(dataset):
    sentences_1 = []
    sentences_2 = []
    
    dataset.reset_index(drop = True, inplace = True)

    for i in tqdm(range(len(dataset))):
        row = dataset.iloc[i]
        pair = row["set"]
        sentences_1.append(str(pair[0]))
        sentences_2.append(str(pair[1]))         
    
    return sentences_1, sentences_2

sentences_1, sentences_2 = create_test_sentences(uns_test)

# %%
from sentence_transformers import SentenceTransformer, util
import numpy as np

model = SentenceTransformer('sentence-transformers/multi-qa-mpnet-base-dot-v1') # untrained score 0.6256573
#model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2') # untrained score 0.5305708
#model = SentenceTransformer('sentence-transformers/multi-qa-distilbert-cos-v1') # untrained score 0.509438
#model = SentenceTransformer('sentence-transformers/paraphrase-distilroberta-base-v2') # untrained score 0.5043382
#model = SentenceTransformer('sentence-transformers/all-distilroberta-v1') # untrained score 0.49077263

#Compute embedding for both lists
embeddings_1 = model.encode(sentences_1, show_progress_bar = True, convert_to_tensor = True)
embeddings_2 = model.encode(sentences_2, show_progress_bar = True, convert_to_tensor = True)

#Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings_1, embeddings_2)

scores = []

for i in range(len(cosine_scores) - 1):
    scores.append(cosine_scores[i][i])

scores = np.array(scores)
print(round(scores.mean(), 8))

del embeddings_1, embeddings_2, cosine_scores
# Out:
# Batches: 100%|██████████| 798/798 [02:19<00:00,  5.73it/s]
# Batches: 100%|██████████| 798/798 [02:44<00:00,  4.86it/s]

# %%
#Hence, choose 'multi-qa-mpnet-base-dot-v1' as the basic retriever model

# %% [markdown]
# ## Fine-tune *'multi-qa-mpnet-base-dot-v1'* from *'HuggingFace Library'* on the dataset from `uns_train.csv`.
#
# Here, instead of PyTorch, we use the HuggingFace SageMaker Python SDK.

# %%
model_name = 'sentence-transformers/multi-qa-mpnet-base-dot-v1'

# %%
# hyperparameters, which are passed into the training job
hyperparameters = {'epochs': 2,
                   'batch_size': 32,
                   'model_name': model_name
                  }

# %%
# !pygmentize ./uns_train.py
# Out:
# import csv
# import os
# import pandas as pd
# import boto3
# import json
# from torch.utils.data import DataLoader
# from sentence_transformers import SentenceTransformer, LoggingHandler
# from sentence_transformers import models, util, datasets, evaluation, losses, InputExample
# from datasets import Dataset
# import random
# import logging
# import sys
# import argparse
# import torch
#
#
# def create_train_sentences(dataset):
#     train_examples = []
#     train_data = dataset["set"]
#     n_examples = dataset.num_rows
#
#     for i in range(n_examples):
#         example = train_data[i]
#         train_examples.append(InputExample(texts = [str(example[0]), str(example[1])]))
#
#     return train_examples
#
# def create_test_sentences(dataset):
#     sentences_1 = []
#     sentences_2 = []
#     scores = []
#
#     test_data = dataset["set"]
#     n_examples = dataset.num_rows
#
#     for i in range(n_examples):
#         pair = test_data[i]
#         sentences_1.append(str(pair[0]))
#         sentences_2.append(str(pair[1]))
#         scores.append(1)
#
#     return sentences_1, sentences_2, scores
#
#
# def compute_metrics(pred):
#         """Compute metrics function for binary classification"""
#         labels = pred.label_ids
#         preds = pred.predictions.argmax(-1)
#         precision, recall, f_1, _ = precision_recall_fscore_support(labels, preds, average="binary")
#         acc = accuracy_score(labels, preds)
#         return {"accuracy": acc, "f1": f_1, "precision": precision, "recall": recall}
#
#
# if __name__ == "__main__":
#
#     parser = argparse.ArgumentParser()
#
#     # hyperparameters sent by the client are passed as command-line arguments to the script.
#     parser.add_argument("--epochs", type = int, default = 2)
#     parser.add_argument("--train_batch_size", type = int, default = 32)
#     parser.add_argument("--warmup_steps", type = int, default = 500)
#     parser.add_argument("--model_name", type = str)
#     parser.add_argument("--learning_rate", type = str, default = 5e-5)
#
#     # Data, model, and output directories
#     parser.add_argument("--model_dir", type = str, default = os.environ["SM_MODEL_DIR"])
#     parser.add_argument("--training_dir", type = str, default = os.environ["SM_CHANNEL_TRAIN"])
#     parser.add_argument("--testing_dir", type = str, default = os.environ["SM_CHANNEL_TEST"])
#
#     args, _ = parser.parse_known_args()
#
#     # Set up logging
#     logger = logging.getLogger(__name__)
#
#     logging.basicConfig(
#         level = logging.getLevelName("INFO"),
#         handlers = [logging.StreamHandler(sys.stdout)],
#         format = "%(asctime)s - %(name)s - %(levelname)s - %(message)s",
#     )
#
#     word_embedding_model = models.Transformer(args.model_name)
#     pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension(),
#                                    pooling_mode_mean_tokens = False,
#                                    pooling_mode_cls_token = True)
#     model = SentenceTransformer(modules = [word_embedding_model, pooling_model])
#
#     # read data
#     print('******* list files *********: ', os.listdir(args.training_dir))
#     print('********************** Reading Data *************************')
#     train_data = pd.read_csv(os.path.join(args.training_dir, 'uns_train.csv'), index_col = 0)
#     test_data = pd.read_csv(os.path.join(args.training_dir, 'uns_test.csv'), index_col = 0)
#
#     train_dataset = Dataset.from_pandas(train_data)
#     train_examples = create_train_sentences(train_dataset)
#     train_dataloader = DataLoader(train_examples, batch_size = args.train_batch_size, shuffle = True)
#
#     # Since we have only positive pairs, use 'MultipleNegativesRankingLoss'
#     train_loss = losses.MultipleNegativesRankingLoss(model = model)
#
#     test_dataset = Dataset.from_pandas(test_data)
#     sentences_1, sentences_2, scores = create_test_sentences(test_dataset)
#
#     evaluator = evaluation.EmbeddingSimilarityEvaluator(sentences_1, sentences2, scores)
#
#     #call the fit method
#     model.fit(train_objectives = [(train_dataloader, train_loss)],
#               epochs = args.epochs,
#               warmup_steps = args.warmup_steps,
#               weight_decay = 0,
#               scheduler = 'constantlr',
#               optimizer_params = {'lr': args.learning_rate},
#               evaluator = evaluator,
#               #evaluation_steps = 500,
#               show_progress_bar = True
#               #output_path = args.model_dir
#              )
#
#     model.save(args.model_dir)

# %%
from sagemaker.huggingface import HuggingFace
from sagemaker.huggingface import HuggingFaceModel

huggingface_estimator = HuggingFace(
    entry_point = 'uns_train.py',
    source_dir = './',
    instance_type = 'ml.p3.2xlarge', # GPU supported by Hugging Face
    instance_count = 1,
    role = role,
    transformers_version = '4.6',
    pytorch_version = '1.7',
    py_version = 'py36',
    hyperparameters = hyperparameters
)

# %%
# starting the train job with our uploaded datasets as input
huggingface_estimator.fit({'train': uns_data_input_path}, wait = True)
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: huggingface-pytorch-training-2023-04-06-02-59-07-964
# 2023-04-06 03:06:20 Starting - Starting the training job...
# 2023-04-06 03:06:47 Starting - Preparing the instances for trainingProfilerReport-1680750380: InProgress
# .........
# 2023-04-06 03:08:06 Downloading - Downloading input data...
# 2023-04-06 03:08:47 Training - Downloading the training image............
# 2023-04-06 03:10:47 Training - Training image download completed. Training in progress....bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-04-06 03:11:10,791 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-04-06 03:11:10,822 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-04-06 03:11:10,825 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-04-06 03:11:36,041 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /opt/conda/bin/python3.6 -m pip install -r requirements.txt
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (4.6.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 3)) (1.1.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (1.19.1)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 5)) (1.17.79)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (4.49.0)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (1.7.1)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (0.24.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (1.5.4)
# Collecting nltk
#   Downloading nltk-3.6.7-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (0.1.91)
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (4.0.1)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (0.0.45)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (0.10.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (2.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (20.9)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (0.8)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (2021.4.4)
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (5.4.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers->-r requirements.txt (line 1)) (3.10.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->transformers->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.6/site-packages (from pandas->-r requirements.txt (line 3)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas->-r requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3->-r requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.79 in /opt/conda/lib/python3.6/site-packages (from boto3->-r requirements.txt (line 5)) (1.20.79)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /opt/conda/lib/python3.6/site-packages (from boto3->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.79->boto3->-r requirements.txt (line 5)) (1.25.11)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata->transformers->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.6/site-packages (from nltk->sentence-transformers->-r requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.6/site-packages (from nltk->sentence-transformers->-r requirements.txt (line 1)) (1.0.1)
# Collecting regex!=2019.12.17
#   Downloading regex-2022.10.31-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (756 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->transformers->-r requirements.txt (line 2)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->transformers->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->transformers->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.6/site-packages (from torchvision->sentence-transformers->-r requirements.txt (line 1)) (8.2.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py): started
#   Building wheel for sentence-transformers (setup.py): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125919 sha256=0746e051b30e8904c38ecf5ec45ea899d7c4f869833a10fc982ff70203e0d75b
#   Stored in directory: /root/.cache/pip/wheels/c9/90/11/0e58d454669bc8daf94e04a8da9956aa6f78eb10cddb16dd4e
# Successfully built sentence-transformers
# Installing collected packages: regex, tokenizers, huggingface-hub, transformers, nltk, sentence-transformers
#   Attempting uninstall: regex
#     Found existing installation: regex 2021.4.4
#     Uninstalling regex-2021.4.4:
#       Successfully uninstalled regex-2021.4.4
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.10.3
#     Uninstalling tokenizers-0.10.3:
#       Successfully uninstalled tokenizers-0.10.3
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.0.8
#     Uninstalling huggingface-hub-0.0.8:
#       Successfully uninstalled huggingface-hub-0.0.8
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.6.1
#     Uninstalling transformers-4.6.1:
#       Successfully uninstalled transformers-4.6.1
# Successfully installed huggingface-hub-0.4.0 nltk-3.6.7 regex-2022.10.31 sentence-transformers-2.2.2 tokenizers-0.12.1 transformers-4.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 1.6.2 requires huggingface-hub<0.1.0, but you have huggingface-hub 0.4.0 which is incompatible.
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# 2023-04-06 03:11:47,351 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 32,
#         "epochs": 2,
#         "model_name": "sentence-transformers/multi-qa-mpnet-base-dot-v1"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "huggingface-pytorch-training-2023-04-06-02-59-07-964",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-852055550328/huggingface-pytorch-training-2023-04-06-02-59-07-964/source/sourcedir.tar.gz",
#     "module_name": "uns_train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.p3.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p3.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "uns_train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":32,"epochs":2,"model_name":"sentence-transformers/multi-qa-mpnet-base-dot-v1"}
# SM_USER_ENTRY_POINT=uns_train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=uns_train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-852055550328/huggingface-pytorch-training-2023-04-06-02-59-07-964/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":32,"epochs":2,"model_name":"sentence-transformers/multi-qa-mpnet-base-dot-v1"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-pytorch-training-2023-04-06-02-59-07-964","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-852055550328/huggingface-pytorch-training-2023-04-06-02-59-07-964/source/sourcedir.tar.gz","module_name":"uns_train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"uns_train.py"}
# SM_USER_ARGS=["--batch_size","32","--epochs","2","--model_name","sentence-transformers/multi-qa-mpnet-base-dot-v1"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH_SIZE=32
# SM_HP_EPOCHS=2
# SM_HP_MODEL_NAME=sentence-transformers/multi-qa-mpnet-base-dot-v1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 uns_train.py --batch_size 32 --epochs 2 --model_name sentence-transformers/multi-qa-mpnet-base-dot-v1
# 2023-04-06 03:11:49,949 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/multi-qa-mpnet-base-dot-v1
# 2023-04-06 03:11:50,025 - filelock - INFO - Lock 139799088000920 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/.gitattributes.lock
# 2023-04-06 03:11:50,055 - filelock - INFO - Lock 139799088000920 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/.gitattributes.lock
# 2023-04-06 03:11:50,084 - filelock - INFO - Lock 139799087999352 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/1_Pooling/config.json.lock
# 2023-04-06 03:11:50,109 - filelock - INFO - Lock 139799087999352 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/1_Pooling/config.json.lock
# 2023-04-06 03:11:50,131 - filelock - INFO - Lock 139799088000920 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/README.md.lock
# 2023-04-06 03:11:50,159 - filelock - INFO - Lock 139799088000920 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/README.md.lock
# 2023-04-06 03:11:50,180 - filelock - INFO - Lock 139799087999240 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/config.json.lock
# 2023-04-06 03:11:50,213 - filelock - INFO - Lock 139799087999240 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/config.json.lock
# 2023-04-06 03:11:50,242 - filelock - INFO - Lock 139799087999184 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/config_sentence_transformers.json.lock
# 2023-04-06 03:11:50,271 - filelock - INFO - Lock 139799087999184 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/config_sentence_transformers.json.lock
# 2023-04-06 03:11:50,294 - filelock - INFO - Lock 139799087999240 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/data_config.json.lock
# 2023-04-06 03:11:50,324 - filelock - INFO - Lock 139799087999240 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/data_config.json.lock
# 2023-04-06 03:11:50,350 - filelock - INFO - Lock 139799087999184 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/pytorch_model.bin.lock
# 2023-04-06 03:11:57,849 - filelock - INFO - Lock 139799087999184 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/pytorch_model.bin.lock
# 2023-04-06 03:11:57,877 - filelock - INFO - Lock 139799087999240 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/sentence_bert_config.json.lock
# 2023-04-06 03:11:57,904 - filelock - INFO - Lock 139799087999240 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/sentence_bert_config.json.lock
# 2023-04-06 03:11:57,934 - filelock - INFO - Lock 139799087999184 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/special_tokens_map.json.lock
# 2023-04-06 03:11:57,960 - filelock - INFO - Lock 139799087999184 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/special_tokens_map.json.lock
# 2023-04-06 03:11:57,984 - filelock - INFO - Lock 139799087999240 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/tokenizer.json.lock
# 2023-04-06 03:11:58,072 - filelock - INFO - Lock 139799087999240 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/tokenizer.json.lock
# 2023-04-06 03:11:58,096 - filelock - INFO - Lock 139799087999184 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/tokenizer_config.json.lock
# 2023-04-06 03:11:58,123 - filelock - INFO - Lock 139799087999184 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/tokenizer_config.json.lock
# 2023-04-06 03:11:58,146 - filelock - INFO - Lock 139799087999240 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/train_script.py.lock
# 2023-04-06 03:11:58,174 - filelock - INFO - Lock 139799087999240 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/train_script.py.lock
# 2023-04-06 03:11:58,197 - filelock - INFO - Lock 139799088155784 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/vocab.txt.lock
# 2023-04-06 03:11:58,250 - filelock - INFO - Lock 139799088155784 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/vocab.txt.lock
# 2023-04-06 03:11:58,279 - filelock - INFO - Lock 139799088153544 acquired on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/modules.json.lock
# 2023-04-06 03:11:58,306 - filelock - INFO - Lock 139799088153544 released on /root/.cache/torch/sentence_transformers/sentence-transformers_multi-qa-mpnet-base-dot-v1/modules.json.lock
# 2023-04-06 03:11:59,890 - sentence_transformers.SentenceTransformer - INFO - Use pytorch device: cuda
# ******* list files *********:  ['correlations.csv', 'train_topics.csv', 'uns_train.csv', 'topics.csv', 'test_topics.csv', 'sample_submission.csv', 'uns_test.csv', 'sup_test.csv', 'content.csv', 'sup_train.csv']
# ********************** Reading Data *************************
# [2023-04-06 03:12:02.881 algo-1:49 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-04-06 03:12:02.926 algo-1:49 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-04-06 03:12:02.927 algo-1:49 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-04-06 03:12:02.927 algo-1:49 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-04-06 03:12:02.928 algo-1:49 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2023-04-06 03:12:02.928 algo-1:49 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-04-06 03:12:03.060 algo-1:49 INFO hook.py:591] name:model.0.auto_model.embeddings.word_embeddings.weight count_params:23444736
# [2023-04-06 03:12:03.060 algo-1:49 INFO hook.py:591] name:model.0.auto_model.embeddings.position_embeddings.weight count_params:394752
# [2023-04-06 03:12:03.060 algo-1:49 INFO hook.py:591] name:model.0.auto_model.embeddings.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.060 algo-1:49 INFO hook.py:591] name:model.0.auto_model.embeddings.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.060 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.0.attention.attn.q.weight count_params:589824
# [2023-04-06 03:12:03.060 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.0.attention.attn.q.bias count_params:768
# [2023-04-06 03:12:03.060 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.0.attention.attn.k.weight count_params:589824
# [2023-04-06 03:12:03.060 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.0
algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.attention.attn.q.bias count_params:768
# [2023-04-06 03:12:03.072 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.attention.attn.k.weight count_params:589824
# [2023-04-06 03:12:03.072 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.attention.attn.k.bias count_params:768
# [2023-04-06 03:12:03.072 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.attention.attn.v.weight count_params:589824
# [2023-04-06 03:12:03.072 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.attention.attn.v.bias count_params:768
# [2023-04-06 03:12:03.072 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.attention.attn.o.weight count_params:589824
# [2023-04-06 03:12:03.072 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.attention.attn.o.bias count_params:768
# [2023-04-06 03:12:03.072 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.attention.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.072 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.attention.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.072 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.intermediate.dense.weight count_params:2359296
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.intermediate.dense.bias count_params:3072
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.output.dense.weight count_params:2359296
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.output.dense.bias count_params:768
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.output.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.7.output.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.attn.q.weight count_params:589824
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.attn.q.bias count_params:768
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.attn.k.weight count_params:589824
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.attn.k.bias count_params:768
# [2023-04-06 03:12:03.073 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.attn.v.weight count_params:589824
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.attn.v.bias count_params:768
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.attn.o.weight count_params:589824
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.attn.o.bias count_params:768
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.attention.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.intermediate.dense.weight count_params:2359296
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.intermediate.dense.bias count_params:3072
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.output.dense.weight count_params:2359296
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.output.dense.bias count_params:768
# [2023-04-06 03:12:03.074 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.output.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.075 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.8.output.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.075 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.attn.q.weight count_params:589824
# [2023-04-06 03:12:03.075 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.attn.q.bias count_params:768
# [2023-04-06 03:12:03.075 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.attn.k.weight count_params:589824
# [2023-04-06 03:12:03.075 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.attn.k.bias count_params:768
# [2023-04-06 03:12:03.075 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.attn.v.weight count_params:589824
# [2023-04-06 03:12:03.075 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.attn.v.bias count_params:768
# [2023-04-06 03:12:03.075 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.attn.o.weight count_params:589824
# [2023-04-06 03:12:03.075 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.attn.o.bias count_params:768
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.attention.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.intermediate.dense.weight count_params:2359296
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.intermediate.dense.bias count_params:3072
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.output.dense.weight count_params:2359296
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.output.dense.bias count_params:768
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.output.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.9.output.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.attn.q.weight count_params:589824
# [2023-04-06 03:12:03.076 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.attn.q.bias count_params:768
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.attn.k.weight count_params:589824
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.attn.k.bias count_params:768
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.attn.v.weight count_params:589824
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.attn.v.bias count_params:768
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.attn.o.weight count_params:589824
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.attn.o.bias count_params:768
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.attention.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.intermediate.dense.weight count_params:2359296
# [2023-04-06 03:12:03.077 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.intermediate.dense.bias count_params:3072
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.output.dense.weight count_params:2359296
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.output.dense.bias count_params:768
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.output.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.10.output.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.attn.q.weight count_params:589824
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.attn.q.bias count_params:768
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.attn.k.weight count_params:589824
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.attn.k.bias count_params:768
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.attn.v.weight count_params:589824
# [2023-04-06 03:12:03.078 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.attn.v.bias count_params:768
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.attn.o.weight count_params:589824
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.attn.o.bias count_params:768
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.attention.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.intermediate.dense.weight count_params:2359296
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.intermediate.dense.bias count_params:3072
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.output.dense.weight count_params:2359296
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.output.dense.bias count_params:768
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.output.LayerNorm.weight count_params:768
# [2023-04-06 03:12:03.079 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.layer.11.output.LayerNorm.bias count_params:768
# [2023-04-06 03:12:03.080 algo-1:49 INFO hook.py:591] name:model.0.auto_model.encoder.relative_attention_bias.weight count_params:384
# [2023-04-06 03:12:03.080 algo-1:49 INFO hook.py:591] name:model.0.auto_model.pooler.dense.weight count_params:589824
# [2023-04-06 03:12:03.080 algo-1:49 INFO hook.py:591] name:model.0.auto_model.pooler.dense.bias count_params:768
# [2023-04-06 03:12:03.080 algo-1:49 INFO hook.py:593] Total Trainable Params: 109486464
# [2023-04-06 03:12:03.080 algo-1:49 INFO hook.py:425] Monitoring the collections: losses
# ...
# #015Iteration:  95%|█████████▍| 3773/3986 [10:12<00:34,  6.24it/s]#033[A
# #015Iteration:  95%|█████████▍| 3774/3986 [10:12<00:33,  6.24it/s]#033[A
# #015Iteration:  95%|█████████▍| 3775/3986 [10:12<00:33,  6.23it/s]#033[A
# #015Iteration:  95%|█████████▍| 3776/3986 [10:12<00:33,  6.22it/s]#033[A
# #015Iteration:  95%|█████████▍| 3777/3986 [10:12<00:33,  6.22it/s]#033[A
# #015Iteration:  95%|█████████▍| 3778/3986 [10:13<00:33,  6.21it/s]#033[A
# #015Iteration:  95%|█████████▍| 3779/3986 [10:13<00:33,  6.21it/s]#033[A
# #015Iteration:  95%|█████████▍| 3780/3986 [10:13<00:33,  6.20it/s]#033[A
# #015Iteration:  95%|█████████▍| 3781/3986 [10:13<00:33,  6.20it/s]#033[A
# #015Iteration:  95%|█████████▍| 3782/3986 [10:13<00:32,  6.20it/s]#033[A
# #015Iteration:  95%|█████████▍| 3783/3986 [10:13<00:32,  6.20it/s]#033[A
#uns_model_location = 's3://sagemaker-us-east-1-852055550328/huggingface-pytorch-training-2023-04-06-00-25-59-604/output/model.tar.gz'
#uns_model_location = 's3://sagemaker-us-east-1-852055550328/huggingface-pytorch-training-2023-04-06-02-15-06-088/output/model.tar.gz'
uns_model_location = 's3://sagemaker-us-east-1-852055550328/huggingface-pytorch-training-2023-04-06-02-59-07-964/output/model.tar.gz'

# %% [markdown]
# ## Deploy the fine-tuned transformer

# %%
from sagemaker.huggingface import HuggingFace
from sagemaker.huggingface import HuggingFaceModel

# Create Hugging Face Model Class

huggingface_model = HuggingFaceModel(
    model_data = uns_model_location,  # path to your trained sagemaker model
    entry_point = 'uns_inference.py',
    role = role, # iam role with permissions to create an Endpoint
    transformers_version = "4.6", # transformers version used
    pytorch_version = "1.7", # pytorch version used
    py_version = "py36", # python version of the DLC
)

# %%
# !pygmentize ./uns_inference.py
# Out:
# from transformers import AutoTokenizer, AutoModel
# import torch
# import torch.nn.functional as F
#
# #def mean_pooling(model_output, attention_mask):
# #    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
# #    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
# #    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min = 1e-9)
#
# #CLS Pooling - Take output from first token
# def cls_pooling(model_output):
#     return model_output.last_hidden_state[: , 0]
#
#
# def model_fn(model_dir):
#     # Load model
#     tokenizer = AutoTokenizer.from_pretrained(model_dir)
#     model = AutoModel.from_pretrained(model_dir)
#     return model, tokenizer
#
# def predict_fn(data, model_and_tokenizer):
#     # destruct model and tokenizer
#     model, tokenizer = model_and_tokenizer
#
#     # Tokenize sentences
#     sentences = data.pop("inputs", data)
#     encoded_input = tokenizer(sentences, padding = True, truncation = True, return_tensors = 'pt')
#
#     # Compute token embeddings
#     with torch.no_grad():
#         model_output = model(**encoded_input, return_dict = True)
#
#     # Perform pooling
#     #sentence_embedding = mean_pooling(model_output, encoded_input['attention_mask'])
#     sentence_embedding = cls_pooling(model_output)
#
#     # Normalize embeddings
#     #sentence_embedding = F.normalize(sentence_embedding, p = 2, dim = 1)
#
#     # return dictonary, which will be json serializable
#     return {"vectors" : sentence_embedding[0].tolist()}

# %%
#Inference using endpoint deployment

encoder = huggingface_model.deploy(
    initial_instance_count = 1,
    instance_type = "ml.m5.xlarge"
)
# Out:
# INFO:sagemaker:Creating model with name: huggingface-pytorch-inference-2023-04-06-03-38-00-247
# INFO:sagemaker:Creating endpoint-config with name huggingface-pytorch-inference-2023-04-06-03-38-01-046
# INFO:sagemaker:Creating endpoint with name huggingface-pytorch-inference-2023-04-06-03-38-01-046
# -----!

# %% [markdown]
# ## Check performance of the fine-tuned encoder

# %%
from tqdm import tqdm
from sklearn.model_selection import train_test_split

uns_train , uns_test = train_test_split(uns_dataset, test_size = 0.01)

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

uns_test.reset_index(drop = True, inplace = True)

scores = []
counter = 0

for i in tqdm(range(len(uns_test))):
    row = uns_test.iloc[i]
    pair = row["set"]
    topic_title = str(pair[0])
    content_title = str(pair[1])
    
    topic_data_str = json.dumps({"inputs" : topic_title})
    topic_data = json.loads(topic_data_str)
    topic_embed = encoder.predict(topic_data)
    vec_1 = topic_embed["vectors"]
    
    content_data_str = json.dumps({"inputs" : content_title})
    content_data = json.loads(content_data_str)
    content_embed = encoder.predict(content_data)
    vec_2 = content_embed["vectors"]
    
    scores.append(cosine_similarity([vec_1], [vec_2]))
    
scores = np.array(scores)
print(round(scores.mean(), 8))
# Out:
# 100%|██████████| 1276/1276 [03:57<00:00,  5.37it/s]
# 0.8861534

# %%
#Note that the performance improved

# %% [markdown]
# ## Split topics into training and testing subsets. Save the datasets to `train_topics.csv` and `test_topics.csv`
#
# Take 5% for testing

# %%
# %%time

import pandas as pd

def read_data(DATA_PATH):
    topics = pd.read_csv(DATA_PATH + "topics.csv")
    content = pd.read_csv(DATA_PATH + "content.csv")
    sample_submission = pd.read_csv(DATA_PATH + "sample_submission.csv")
    
    # Merge topics with sample submission to only infer test topics
    #topics = topics.merge(sample_submission, how = 'inner', left_on = 'id', right_on = 'topic_id')
    
    topics = topics[topics['title'].notna()]
    content = content[content['title'].notna()]
    
    topics = topics[topics['language'] == 'en']
    content = content[content['language'] == 'en']
    
    # Fillna titles
    #topics['title'].fillna("", inplace = True)
    #content['title'].fillna("", inplace = True)
    
    # Sort by title length to make inference faster
    topics['length'] = topics['title'].apply(lambda x: len(x))
    content['length'] = content['title'].apply(lambda x: len(x))
    topics.sort_values('length', inplace = True)
    content.sort_values('length', inplace = True)
    
    # Drop cols
    #topics.drop(['description', 'channel', 'category', 'level', 'language', 'parent', 'has_content', 'length', 'topic_id', 'content_ids'], axis = 1, inplace = True)
    #content.drop(['description', 'kind', 'language', 'text', 'copyright_holder', 'license', 'length'], axis = 1, inplace = True)
    
    # Drop cols
    topics.drop(['description', 'channel', 'category', 'level', 'language', 'parent', 'has_content', 'length'], axis = 1, inplace = True)
    content.drop(['description', 'kind', 'language', 'text', 'copyright_holder', 'license', 'length'], axis = 1, inplace = True)
    
    # Reset index
    topics.reset_index(drop = True, inplace = True)
    content.reset_index(drop = True, inplace = True)
    print(' ')
    print('-' * 50)
    print(f"topics.shape: {topics.shape}")
    print(f"content.shape: {content.shape}")
    return topics, content
# Out:
# CPU times: user 8 µs, sys: 3 µs, total: 11 µs
# Wall time: 13.1 µs

# %%
DATA_PATH = "./Kaggle/"
topics, content = read_data(DATA_PATH)
# Out:
#
# --------------------------------------------------
# topics.shape: (36160, 2)
# content.shape: (65939, 2)

# %%
from sklearn.model_selection import train_test_split

train_topics , test_topics = train_test_split(topics, test_size = 0.05)

print(' ')
print('-' * 50)
print(train_topics.shape)
print(test_topics.shape)
# Out:
#
# --------------------------------------------------
# (34352, 2)
# (1808, 2)

# %%
#Save train and test topics lists

train_topics.to_csv('train_topics.csv')
test_topics.to_csv('test_topics.csv')

boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train_topics.csv')).upload_file('train_topics.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'test_topics.csv')).upload_file('test_topics.csv')

# %% [markdown]
# ## Construct embeddings for training topics, testing topics and content items
#
# We map all topic and content item titles to 768-dimensional real-valued vectors

# %%
train_topics = pd.read_csv("train_topics.csv")
test_topics = pd.read_csv("test_topics.csv")

# %%
title_list = train_topics['title'].tolist()

# %%
# Use the retriever model to get embeddings for topic and content item titles
from tqdm import tqdm

def get_embeddings(df, model):
    
    data_embeddings = []
    title_list = df['title'].tolist()
    
    for i in tqdm(range(len(title_list))):
        title = title_list[i]
        title_data_str = json.dumps({"inputs" : title})
        title_data = json.loads(title_data_str)
        title_embed = encoder.predict(title_data)
        data_embeddings.append(title_embed["vectors"])
    
    return data_embeddings

# %%
train_topics_embeddings = get_embeddings(train_topics, encoder)
# Out:
# 100%|██████████| 34352/34352 [50:22<00:00, 11.37it/s]

# %%
train_te = pd.DataFrame(train_topics_embeddings)
train_te.to_csv('train_topics_embeddings.csv')

# %%
test_topics_embeddings = get_embeddings(test_topics, encoder)
# Out:
# 100%|██████████| 1808/1808 [02:39<00:00, 11.30it/s]

# %%
test_te = pd.DataFrame(test_topics_embeddings)
test_te.to_csv('test_topics_embeddings.csv')

# %%
content_embeddings = get_embeddings(content, encoder)
# Out:
# 100%|██████████| 65939/65939 [1:46:39<00:00, 10.30it/s]

# %%
ce = pd.DataFrame(content_embeddings)
ce.to_csv('content_embeddings.csv')

# %%
# The retriever model is not needed any more, so we delete the endpoint
encoder.delete_endpoint()

# %% [markdown]
# ## Split content item embeddings into classes of nearest neighbours
#
# We split content title vectors into clusters of 50 nearest neighbors using the KNN algorithm.

# %%
train_topics_embeddings = pd.read_csv("train_topics_embeddings.csv")
content_embeddings = pd.read_csv("content_embeddings.csv")

# %%
train_topics_embeddings = train_topics_embeddings.values.tolist()
content_embeddings = content_embeddings.values.tolist()

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import cross_val_score
import numpy as np

neighbors_model = NearestNeighbors(n_neighbors = 50, 
                                   metric = 'cosine',
                                   algorithm = 'brute',
                                   n_jobs = -1
                                  )
neighbors_model.fit(content_embeddings)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=50)

# %%
distances, indices = neighbors_model.kneighbors(train_topics_embeddings)

# %%
train_topics = pd.read_csv("train_topics.csv")

# %%
predictions = []
for k in range(len(indices)):
    pred = indices[k]
    p = ' '.join([content.loc[ind, 'id'] for ind in pred])
    predictions.append(p)
    
train_topics['predictions'] = predictions

# %%
# This is the output of the retriever for the train topics dataset
train_topics.to_csv('train_topics_with_retrieved_content.csv')

# %%
del train_topics_embeddings, content_embeddings, distances, indices

# %% [markdown]
# ## Build a training dataset from `train_topics_with_retrieved_content.csv` and save it to `sup_train.csv`

# %%
import pandas as pd

train_topics = pd.read_csv('train_topics_with_retrieved_content.csv')
train_topics.drop(['Unnamed: 0'], axis = 1, inplace = True)

print(' ')
print('-' * 50)
print(train_topics.shape)
# Out:
#
# --------------------------------------------------
# (34352, 4)

# %%
DATA_PATH = "./Kaggle/"
topics, content = read_data(DATA_PATH)

content.set_index('id', inplace = True)
train_topics.reset_index(drop = True, inplace = True)
correlations_df.set_index('topic_id', inplace = True)
# Out:
#
# --------------------------------------------------
# topics.shape: (36160, 2)
# content.shape: (65939, 2)

# %%
import gc
from tqdm import tqdm

def build_sup_train_set(topics, content, correlations):
    # Create lists for training
    topics_ids = []
    content_ids = []
    title1 = []
    title2 = []
    label = []
    
    # Iterate over each topic
    for k in tqdm(range(len(topics))):
        row = topics.iloc[k]
        topics_id = row['id']
        topics_title = row['title']
        predictions = row['predictions'].split(' ')
        true_content = []
        if topics_id in correlations.index:
            true_content = correlations.loc[topics_id, 'content_ids'].split(' ')
        
        for pred in predictions:
            content_title = content.loc[pred, 'title']
            topics_ids.append(topics_id)
            content_ids.append(pred)
            title1.append(topics_title)
            title2.append(content_title)
            if pred in true_content:
                label.append(1)
            else:
                label.append(0)
                
        for item in true_content:
            if item in content.index:
                content_title = content.loc[item, 'title']
            else:
                continue
            topics_ids.append(topics_id)
            content_ids.append(item)
            title1.append(topics_title)
            title2.append(content_title)
            label.append(1)

    # Build training dataset
    train = pd.DataFrame(
        {'topics_ids': topics_ids, 
         'content_ids': content_ids, 
         'title1': title1, 
         'title2': title2,
         'label' : label
        }
    )
    # Release memory
    del topics_ids, content_ids, title1, title2, label

    return train

# %%
sup_train_set = build_sup_train_set(train_topics, content, correlations_df)
# Out:
# 100%|██████████| 34352/34352 [00:21<00:00, 1619.36it/s]

# %%
sup_train_set.to_csv('sup_train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'sup_train.csv')).upload_file('sup_train.csv')

# %% [markdown]
# ## Train reranker on the dataset from `sup_train.csv`
#
# Choose `all-mpnet-base-v2' as a base model for the reranker

# %%
sup_training_input_path = 's3://sagemaker-us-east-1-852055550328/sentencetransformer/input/'

# %%
# Hyperparameters that are passed into the training job
sup_hyperparameters = {'epochs': 2,
                       'batch_size': 32,
                       'model_name': 'sentence-transformers/all-mpnet-base-v2'
                      }

# %%
from sagemaker.pytorch import PyTorch

reranker = PyTorch(
    entry_point = 'sup_train.py',
    source_dir = './',
    role = role,
    instance_count = 1,
    instance_type = "ml.p3.2xlarge",
    hyperparameters = sup_hyperparameters,
    framework_version = "1.6",
    py_version = "py36"
)

# %%
# Starting the train job of our reranker
reranker.fit({'train': sup_training_input_path}, wait = True)
# Out:
# 2023-04-07 02:05:07 Starting - Starting the training job...ProfilerReport-1680833107: InProgress
# ...
# 2023-04-07 02:06:07 Starting - Preparing the instances for training......
# 2023-04-07 02:07:07 Downloading - Downloading input data......
# 2023-04-07 02:08:07 Training - Downloading the training image......
# 2023-04-07 02:09:08 Training - Training image download completed. Training in progress....bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-04-07 02:09:23,389 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-04-07 02:09:23,420 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-04-07 02:09:23,422 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-04-07 02:09:56,241 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /opt/conda/bin/python3.6 -m pip install -r requirements.txt
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 3)) (1.1.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (1.19.1)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 5)) (1.17.52)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from boto3->-r requirements.txt (line 5)) (0.3.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3->-r requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.52 in /opt/conda/lib/python3.6/site-packages (from boto3->-r requirements.txt (line 5)) (1.20.52)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.52->boto3->-r requirements.txt (line 5)) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.52->boto3->-r requirements.txt (line 5)) (1.25.11)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.52->boto3->-r requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas->-r requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (4.51.0)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (0.24.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.6/site-packages (from sentence-transformers->-r requirements.txt (line 1)) (1.5.2)
# Collecting nltk
#   Downloading nltk-3.6.7-py3-none-any.whl (1.5 MB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (2.25.1)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (0.8)
# Collecting filelock
#   Downloading filelock-3.4.1-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (20.9)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
# Collecting regex!=2019.12.17
#   Downloading regex-2022.10.31-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (756 kB)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.6/site-packages (from transformers->-r requirements.txt (line 2)) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging>=20.0->transformers->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: future in /opt/conda/lib/python3.6/site-packages (from torch>=1.6.0->sentence-transformers->-r requirements.txt (line 1)) (0.18.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata->transformers->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.6/site-packages (from nltk->sentence-transformers->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.6/site-packages (from nltk->sentence-transformers->-r requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->transformers->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->transformers->-r requirements.txt (line 2)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->transformers->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.6/site-packages (from torchvision->sentence-transformers->-r requirements.txt (line 1)) (8.2.0)
# Building wheels for collected packages: sentence-transformers, sacremoses
#   Building wheel for sentence-transformers (setup.py): started
#   Building wheel for sentence-transformers (setup.py): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125919 sha256=9e3e42c3bc3809790b657f09f825f5ffca7d6adbcd286e8128439677c48430a0
#   Stored in directory: /root/.cache/pip/wheels/c9/90/11/0e58d454669bc8daf94e04a8da9956aa6f78eb10cddb16dd4e
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895252 sha256=e6f2db450e8f3f8d3ca68846af661672c225f17ace5289546baefc15d977d1d4
#   Stored in directory: /root/.cache/pip/wheels/4c/64/31/e9900a234b23fb3e9dc565d6114a9d6ff84a72dbdd356502b4
# Successfully built sentence-transformers sacremoses
# Installing collected packages: regex, filelock, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, nltk, sentence-transformers
# Successfully installed filelock-3.4.1 huggingface-hub-0.4.0 nltk-3.6.7 regex-2022.10.31 sacremoses-0.0.53 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.12.1 transformers-4.18.0
# 2023-04-07 02:10:07,765 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 32,
#         "epochs": 2,
#         "model_name": "sentence-transformers/all-mpnet-base-v2"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2023-04-07-01-56-44-331",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-852055550328/pytorch-training-2023-04-07-01-56-44-331/source/sourcedir.tar.gz",
#     "module_name": "sup_train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.p3.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p3.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "sup_train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":32,"epochs":2,"model_name":"sentence-transformers/all-mpnet-base-v2"}
# SM_USER_ENTRY_POINT=sup_train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=sup_train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-852055550328/pytorch-training-2023-04-07-01-56-44-331/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":32,"epochs":2,"model_name":"sentence-transformers/all-mpnet-base-v2"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2023-04-07-01-56-44-331","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-852055550328/pytorch-training-2023-04-07-01-56-44-331/source/sourcedir.tar.gz","module_name":"sup_train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"sup_train.py"}
# SM_USER_ARGS=["--batch_size","32","--epochs","2","--model_name","sentence-transformers/all-mpnet-base-v2"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH_SIZE=32
# SM_HP_EPOCHS=2
# SM_HP_MODEL_NAME=sentence-transformers/all-mpnet-base-v2
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 sup_train.py --batch_size 32 --epochs 2 --model_name sentence-transformers/all-mpnet-base-v2
# Running on Device cuda:0
# Hyperparameters: Batch Size: 32, number of epochs: 2
# --------------------------------------------------
# train.shape: (1838786, 6)
# correlations.shape: (61517, 1)
# max_len: 73
# [2023-04-07 02:14:23.637 algo-1:55 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-04-07 02:14:23.749 algo-1:55 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-04-07 02:14:23.749 algo-1:55 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-04-07 02:14:23.750 algo-1:55 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-04-07 02:14:23.751 algo-1:55 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2023-04-07 02:14:23.751 algo-1:55 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-04-07 02:14:23.756 algo-1:55 INFO hook.py:584] name:model.embeddings.word_embeddings.weight count_params:23444736
# [2023-04-07 02:14:23.756 algo-1:55 INFO hook.py:584] name:model.embeddings.position_embeddings.weight count_params:394752
# [2023-04-07 02:14:23.756 algo-1:55 INFO hook.py:584] name:model.embeddings.LayerNorm.weight count_params:768
# [2023-04-07 02:14:23
# Epoch: [1][29000/51715] Elapsed 51m 49s (remain 40m 35s) Loss: 0.29210353(0.17122141) Grad: 5.89158678  LR: 0.00000904
# Epoch: [1][29500/51715] Elapsed 52m 42s (remain 39m 41s) Loss: 0.01728948(0.17030518) Grad: 1.21674740  LR: 0.00000899
# Epoch: [1][30000/51715] Elapsed 53m 36s (remain 38m 48s) Loss: 0.19713540(0.16939187) Grad: 6.61758423  LR: 0.00000894
# Epoch: [1][30500/51715] Elapsed 54m 30s (remain 37m 54s) Loss: 0.04352473(0.16862144) Grad: 4.63719177  LR: 0.00000889
# Epoch: [1][31000/51715] Elapsed 55m 24s (remain 37m 1s) Loss: 0.22456188(0.16795674) Grad: 7.08875942  LR: 0.00000883
# Epoch: [1][31500/51715] Elapsed 56m 17s (remain 36m 7s) Loss: 0.09124985(0.16738912) Grad: 2.23058748  LR: 0.00000878
# Epoch: [1][32000/51715] Elapsed 57m 11s (remain 35m 13s) Loss: 0.18245709(0.16656885) Grad: 3.32786775  LR: 0.00000872
# Epoch: [1][32500/51715] Elapsed 58m 4s (remain 34m 20s) Loss: 0.01306526(0.16584962) Grad: 0.58564419  LR: 0.00000867
# Epoch: [1][33000/51715] Elapsed 58m 58s (remain 33m 26s) Loss: 0.00878089(0.16518036) Grad: 0.72233474  LR: 0.00000861
# Epoch: [1][33500/51715] Elapsed 59m 52s (remain 32m 32s) Loss: 0.46366853(0.16449184) Grad: 13.17889309  LR: 0.00000855
# Epoch: [1][34000/51715] Elapsed 60m 45s (remain 31m 39s) Loss: 0.12031301(0.16383902) Grad: 13.70406723  LR: 0.00000849
# Epoch: [1][34500/51715] Elapsed 61m 39s (remain 30m 45s) Loss: 0.04233610(0.16314894) Grad: 3.65535092  LR: 0.00000843
# Epoch: [1][35000/51715] Elapsed 62m 33s (remain 29m 52s) Loss: 0.00850530(0.16245708) Grad: 0.47516158  LR: 0.00000837
# Epoch: [1][35500/51715] Elapsed 63m 26s (remain 28m 58s) Loss: 0.15439512(0.16186165) Grad: 8.24651241  LR: 0.00000830
# Epoch: [1][36000/51715] Elapsed 64m 20s (remain 28m 4s) Loss: 0.11327216(0.16121841) Grad: 3.20580435  LR: 0.00000824
# Epoch: [1][36500/51715] Elapsed 65m 14s (remain 27m 11s) Loss: 0.02539060(0.16062243) Grad: 0.84536785  LR: 0.00000817
# Epoch: [1][37000/51715] Elapsed 66m 7s (remain 26m 17s) Loss: 0.07043301(0.16004787) Grad: 8.24895573  LR: 0.00000811
# ...
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# sup_train.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_val['predictions'] = np.where(val_predictions > thres, 1, 0)
# INFO:__main__:Saving model to /opt/ml/model/model.pth
# INFO:__main__:Model saved!
#
# 2023-04-07 05:30:58 Completed - Training job completed
# ProfilerReport-1680833107: IssuesFound
# Training seconds: 12237
# Billable seconds: 12237

# %% [markdown]
# ## Deploy the reranker

# %%
#sup_model_location = 's3://sagemaker-us-east-1-852055550328/pytorch-training-2023-04-04-20-36-48-263/output/model.tar.gz'
#sup_model_location = 's3://sagemaker-us-east-1-852055550328/pytorch-training-2023-04-06-14-08-26-364/output/model.tar.gz'
sup_model_location = 's3://sagemaker-us-east-1-852055550328/pytorch-training-2023-04-07-01-56-44-331/output/model.tar.gz'

# %%
from sagemaker.pytorch import PyTorchModel

reranker_model = PyTorchModel(model_data = sup_model_location,
                              role = role,
                              entry_point = 'sup_inference.py',
                              source_dir = './',
                              framework_version = "1.6",
                              py_version = "py36"
                             )

# %%
from sagemaker.serializers import CSVSerializer

predictor = reranker_model.deploy(initial_instance_count = 1,
                                  instance_type = "ml.m5.xlarge",
                                  serializer = CSVSerializer()
                                 )
# Out:
# ---------------!

# %%
endpoint_name = 'pytorch-inference-2023-04-08-02-29-21-553'

# %% [markdown]
# ## Retrieve MANY content items for each topic from `test_topics.csv`

# %%
import pandas as pd

test_topics = pd.read_csv("test_topics.csv")

# %%
DATA_PATH = "./Kaggle/"
topics, content = read_data(DATA_PATH)
correlations_df = pd.read_csv(DATA_PATH + "correlations.csv")
# Out:
#
# --------------------------------------------------
# topics.shape: (36160, 2)
# content.shape: (65939, 2)

# %%
test_topics_embeddings = pd.read_csv("test_topics_embeddings.csv")
content_embeddings = pd.read_csv("content_embeddings.csv")

# %%
test_topics_embeddings = test_topics_embeddings.values.tolist()
content_embeddings = content_embeddings.values.tolist()

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

neighbors_model = NearestNeighbors(n_neighbors = 1000, metric = 'cosine')
neighbors_model.fit(content_embeddings)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=1000)

# %%
distances, indices = neighbors_model.kneighbors(test_topics_embeddings)

# %%
predictions = []
for k in range(len(indices)):
    pred = indices[k]
    p = ' '.join([content.loc[ind, 'id'] for ind in pred])
    predictions.append(p)
    
test_topics['predictions'] = predictions

# %%
# This is the output of the retriever
test_topics.to_csv('test_topics_with_retrieved_content.csv')

# %% [markdown]
# ## Test the reranker on a random sample of topics from `test_topics.csv`

# %%
import pandas as pd

test_topics = pd.read_csv('test_topics_with_retrieved_content.csv')
test_topics.shape
# Out:
# (1808, 5)

# %%
DATA_PATH = "./Kaggle/"
topics, content = read_data(DATA_PATH)
correlations_df = pd.read_csv(DATA_PATH + "correlations.csv")

test_sample = test_topics.sample(10)
#test_sample = test_topics

content.set_index('id', inplace = True)
#test_sample.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis = 1, inplace = True)
test_sample.reset_index(drop = True, inplace = True)
# Out:
#
# --------------------------------------------------
# topics.shape: (36160, 2)
# content.shape: (65939, 2)

# %%
import gc
from tqdm import tqdm

def build_sup_test_set(topic_row, content):
    # Create lists for training
    topics_ids = []
    content_ids = []
    title1 = []
    title2 = []

    topics_id = topic_row['id']
    topics_title = topic_row['title']
    predictions = topic_row['predictions'].split(' ')
        
    for pred in predictions:
        content_title = content.loc[pred, 'title']
        topics_ids.append(topics_id)
        content_ids.append(pred)
        title1.append(topics_title)
        title2.append(content_title)

    # Build training dataset
    test = pd.DataFrame(
        {'topics_ids': topics_ids, 
         'content_ids': content_ids, 
         'title1': title1, 
         'title2': title2
        }
    )
    # Release memory
    del topics_ids, content_ids, title1, title2

    return test

# %%
def preprocess_data(data):
    #data['title1'].fillna("Title does not exist", inplace = True)
    #data['title2'].fillna("Title does not exist", inplace = True)
    # Create feature column
    data['text'] = data['title1'] + '[SEP]' + data['title2']
    # Drop titles
    data.drop(['title1', 'title2'], axis = 1, inplace = True)
    # Sort so inference is faster
    data['length'] = data['text'].apply(lambda x: len(x))
    data.sort_values('length', inplace = True)
    data.drop(['length'], axis = 1, inplace = True)
    data.reset_index(drop = True, inplace = True)
    return data

# %%
def f2_score(y_true, y_pred):
    y_true = y_true.astype(str)
    y_pred = y_pred.astype(str)
    y_true = y_true.apply(lambda x: set(x.split(" ")))
    y_pred = y_pred.apply(lambda x: set(x.split(" ")))
    tp = np.array([len(x[0] & x[1]) for x in zip(y_true, y_pred)])
    fp = np.array([len(x[1] - x[0]) for x in zip(y_true, y_pred)])
    fn = np.array([len(x[0] - x[1]) for x in zip(y_true, y_pred)])
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    #f2 = (5 * precision * recall) / (4 * precision + recall)
    f2 = tp / (tp + 0.2 * fp + 0.8 * fn)
    return round(precision.mean(), 8), round(recall.mean(), 8), round(f2.mean(), 8)

# %%
import io
from io import StringIO
import boto3
import numpy as np

client = boto3.client('sagemaker-runtime')
csv_file = io.StringIO()

topic_ids = []
content_ids = []
test = pd.DataFrame()

for k in tqdm(range(len(test_sample))):
    row = test_sample.iloc[k]
    topic_id = row['id']
    topic_preds = build_sup_test_set(row, content)
    topic_preds = preprocess_data(topic_preds)
    
    # by default sagemaker expects comma seperated
    csv_file = io.StringIO()
    topic_preds.to_csv(csv_file, sep = ",", header = ['topics_ids', 'content_ids', 'text'], index = False)
    csv_payload = csv_file.getvalue()
    
    response = client.invoke_endpoint(EndpointName = endpoint_name,
                                      ContentType = "text/csv",
                                      Body = csv_payload
                                     )
        
    result = response["Body"].read().decode()
    result = json.loads(result)
    result = np.array(result)
    
    topic_preds['prediction'] = result
    test = test.append(topic_preds)
# Out:
# 100%|██████████| 10/10 [02:51<00:00, 17.11s/it]

# %%
threshold = 0.06

test['predictions'] = np.where(test['prediction'] > threshold, 1, 0)
test1 = test[test['predictions'] == 1]
test1 = test1.groupby(['topics_ids'])['content_ids'].unique().reset_index()
test1['content_ids'] = test1['content_ids'].apply(lambda x: ' '.join(x))
test1.columns = ['topic_id', 'content_ids']
test0 = pd.Series(test['topics_ids'].unique())
test0 = test0[~test0.isin(test1['topic_id'])]
test0 = pd.DataFrame({'topic_id': test0.values, 'content_ids': ""})
test_preds = pd.concat([test1, test0], axis = 0, ignore_index = True)

merged = pd.merge(test_preds, correlations_df, how = 'inner', on = 'topic_id')

y_pred = merged['content_ids_x']
y_true = merged['content_ids_y']

precision, recall, f2 = f2_score(y_true, y_pred)

print("Precision for the sample test set:", precision)
print("Recall for the sample test set:", recall)
print("F2 score for the sample test set:", f2)
# Out:
# Precision for the sample test set: 0.00112973
# Recall for the sample test set: 0.02875408
# F2 score for the sample test set: 0.00408274

# %%
# Delete the reranker endpoint
predictor.delete_endpoint()

# %% [markdown]
# ## References:
# - https://www.kaggle.com/competitions/learning-equality-curriculum-recommendations
# - https://www.sbert.net/examples/applications/retrieve_rerank/README.html
# - https://www.kaggle.com/code/hasanbasriakcay/learning-equality-eda-fe-modeling
# - https://www.kaggle.com/code/ragnar123/lecr-xlm-roberta-base-baseline
